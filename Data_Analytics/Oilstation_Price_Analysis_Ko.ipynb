# %%
import pandas as pd
total_gas_station = pd.read_excel('제주특별자치도_시별주유소가격정보.xlsx')   # 2022.05.29 기준
total_gas_station
# Out:
#           지역           상호                           주소      상표          전화번호  \
# 0    제주특별자치도        토평주유소      제주특별자치도 서귀포시 중산간동로 7801   알뜰주유소  064-762-5151
# 1    제주특별자치도        우수주유소    제주특별자치도 서귀포시 표선면 번영로 3497   알뜰주유소  064-787-1844
# 2    제주특별자치도        염돈주유소  제주특별자치도 서귀포시 일주서로 136 (강정동)   S-OIL  064-739-5400
# 3    제주특별자치도       해맞이주유소   제주특별자치도 서귀포시 성산읍 일주동로 4501   GS칼텍스  064-784-3738
# 4    제주특별자치도        초원주유소   제주특별자치도 서귀포시 일주서로 27 (강정동)   알뜰주유소  064-739-5551
# ..       ...          ...                          ...     ...           ...
# 192  제주특별자치도  구좌농협우도지점주유소      제주특별자치도 제주시 우도면 우도로 147  NH-OIL  064-783-4040
# 193  제주특별자치도       신도시주유소          제주 제주시 과원로 210 (연동)   SK에너지  064-746-5185
# 194  제주특별자치도        인양주유소            제주 제주시 추자면 영흥4길 1    자가상표  064-742-3529
# 195  제주특별자치도        창성주유소         제주 제주시 노형로 315 (노형동)   GS칼텍스  064-713-8951
# 196  제주특별자치도        한림주유소          제주도 제주시 한림읍 한림로 699   SK에너지  064-796-2714
#
#     셀프여부 고급휘발유   휘발유    경유  실내등유
# ...

# %%
gas_station = pd.DataFrame({'주유소명': total_gas_station['상호'],\
'주소': total_gas_station['주소'],\
'휘발유가격': total_gas_station['휘발유'],\
'셀프': total_gas_station['셀프여부'],\
'브랜드': total_gas_station['상표']\
})
gas_station
# Out:
#                    주유소명                              주소 휘발유가격 셀프     브랜드
# 0                 토평주유소         제주특별자치도 서귀포시 중산간동로 7801  2140  N   알뜰주유소
# 1                 우수주유소       제주특별자치도 서귀포시 표선면 번영로 3497  2149  Y   알뜰주유소
# 2                 염돈주유소     제주특별자치도 서귀포시 일주서로 136 (강정동)  2150  N   S-OIL
# 3                해맞이주유소      제주특별자치도 서귀포시 성산읍 일주동로 4501  2150  Y   GS칼텍스
# 4                 초원주유소      제주특별자치도 서귀포시 일주서로 27 (강정동)  2150  N   알뜰주유소
# 5         삼화석유(주) 법환주유소          제주특별자치도 서귀포시 일주동로 9173  2150  N   SK에너지
# 6           자유에너지 가든주유소   제주특별자치도 서귀포시 중산간동로 8338 (호근동)  2150  N    자가상표
# 7                 수산주유소            제주 서귀포시 성산읍 서성일로 898  2150  Y   알뜰주유소
# 8                강정천주유소          제주 서귀포시 이어도로 634 (강정동)  2150  N   SK에너지
# 9                가까운주유소     제주특별자치도 서귀포시 일주서로 1080(상예동)  2160  Y   GS칼텍스
# 10         수도석유(주)한신주유소                 제주 서귀포시 천제연로 77  2160  N   SK에너지
# 11             (주)태흥주유소        제주특별자치도 서귀포시 남원읍 태위로 990  2160  N   알뜰주유소
# ...

# %%
gas_station['구'] = [eachAddress.split()[1] for eachAddress in gas_station['주소']]
gas_station
# Out:
#                    주유소명                              주소 휘발유가격 셀프     브랜드     구
# 0                 토평주유소         제주특별자치도 서귀포시 중산간동로 7801  2140  N   알뜰주유소  서귀포시
# 1                 우수주유소       제주특별자치도 서귀포시 표선면 번영로 3497  2149  Y   알뜰주유소  서귀포시
# 2                 염돈주유소     제주특별자치도 서귀포시 일주서로 136 (강정동)  2150  N   S-OIL  서귀포시
# 3                해맞이주유소      제주특별자치도 서귀포시 성산읍 일주동로 4501  2150  Y   GS칼텍스  서귀포시
# 4                 초원주유소      제주특별자치도 서귀포시 일주서로 27 (강정동)  2150  N   알뜰주유소  서귀포시
# 5         삼화석유(주) 법환주유소          제주특별자치도 서귀포시 일주동로 9173  2150  N   SK에너지  서귀포시
# 6           자유에너지 가든주유소   제주특별자치도 서귀포시 중산간동로 8338 (호근동)  2150  N    자가상표  서귀포시
# 7                 수산주유소            제주 서귀포시 성산읍 서성일로 898  2150  Y   알뜰주유소  서귀포시
# 8                강정천주유소          제주 서귀포시 이어도로 634 (강정동)  2150  N   SK에너지  서귀포시
# 9                가까운주유소     제주특별자치도 서귀포시 일주서로 1080(상예동)  2160  Y   GS칼텍스  서귀포시
# 10         수도석유(주)한신주유소                 제주 서귀포시 천제연로 77  2160  N   SK에너지  서귀포시
# ...

# %%
pd.set_option('display.max_rows', None) # 줄 생략없이 모든 데이터를 출력하도록 설정
gas_station
# Out:
#                    주유소명                              주소 휘발유가격 셀프     브랜드     구
# 0                 토평주유소         제주특별자치도 서귀포시 중산간동로 7801  2140  N   알뜰주유소  서귀포시
# 1                 우수주유소       제주특별자치도 서귀포시 표선면 번영로 3497  2149  Y   알뜰주유소  서귀포시
# 2                 염돈주유소     제주특별자치도 서귀포시 일주서로 136 (강정동)  2150  N   S-OIL  서귀포시
# 3                해맞이주유소      제주특별자치도 서귀포시 성산읍 일주동로 4501  2150  Y   GS칼텍스  서귀포시
# 4                 초원주유소      제주특별자치도 서귀포시 일주서로 27 (강정동)  2150  N   알뜰주유소  서귀포시
# 5         삼화석유(주) 법환주유소          제주특별자치도 서귀포시 일주동로 9173  2150  N   SK에너지  서귀포시
# 6           자유에너지 가든주유소   제주특별자치도 서귀포시 중산간동로 8338 (호근동)  2150  N    자가상표  서귀포시
# 7                 수산주유소            제주 서귀포시 성산읍 서성일로 898  2150  Y   알뜰주유소  서귀포시
# 8                강정천주유소          제주 서귀포시 이어도로 634 (강정동)  2150  N   SK에너지  서귀포시
# 9                가까운주유소     제주특별자치도 서귀포시 일주서로 1080(상예동)  2160  Y   GS칼텍스  서귀포시
# 10         수도석유(주)한신주유소                 제주 서귀포시 천제연로 77  2160  N   SK에너지  서귀포시
# ...

# %%
gas_station = gas_station[gas_station['휘발유가격'] != '-']
gas_station['휘발유가격'] = [float(value) for value in gas_station['휘발유가격']]

gas_station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 194
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   level_0  195 non-null    int64
#  1   index    195 non-null    int64
#  2   주유소명     195 non-null    object
#  3   주소       195 non-null    object
#  4   휘발유가격    195 non-null    float64
#  5   셀프       195 non-null    object
#  6   브랜드      195 non-null    object
#  7   구        195 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 13.7+ KB

# %%
gas_station.reset_index(inplace=True)
gas_station
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-2ed5168dc00f> in <module>()
# ----> 1 gas_station.reset_index(inplace=True)
#       2 gas_station
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5797                     )
#    5798
# -> 5799                 new_obj.insert(0, name, level_values)
#    5800
#    5801         new_obj.index = new_index
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
# ...

# %%
# 그래프에 한글 출력을 위한 폰트 설정
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 런타임 - 런타임 다시 시작 을 클릭하여 런타임을 재시작
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# ...

# %%
gas_station.boxplot(column='휘발유가격', by='셀프')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 55064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50976 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
import seaborn as sns
sns.boxplot(x='브랜드', y='휘발유가격', hue='셀프', data=gas_station)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50508 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50976 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.boxplot(x='셀프', y='경유가격', hue='브랜드', data=gas_station)
plt.show()

# %%
sns.boxplot(x='브랜드', y='경유가격', data=gas_station)
sns.swarmplot(x='브랜드', y='경유가격', data=gas_station)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 61.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 49.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 49.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 43.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
gas_station.sort_values(by='휘발유가격', ascending=False).head(10)
# Out:
#      level_0  index             주유소명                           주소   휘발유가격 셀프  \
# 194      194    194            인양주유소            제주 제주시 추자면 영흥4길 1  2340.0  N
# 64        64     64            대포주유소       제주 서귀포시 일주서로 559 (대포동)  2290.0  Y
# 193      193    193           신도시주유소          제주 제주시 과원로 210 (연동)  2240.0  N
# 192      192    192      구좌농협우도지점주유소      제주특별자치도 제주시 우도면 우도로 147  2220.0  N
# 191      191    191            열린주유소         제주 제주시 한북로 221 (오등동)  2220.0  N
# 136      136    136            도농주유소  제주특별자치도 제주시 일주서로 7410 (내도동)  2210.0  N
# 131      131    131  현대오일뱅크㈜직영 남부주유소        제주 제주시 중앙로 301 (이도이동)  2210.0  N
# 132      132    132            우리주유소           제주 제주시 조천읍 신북로 448  2210.0  N
# 133      133    133            노형주유소      제주 제주시 1100로 3338 (노형동)  2210.0  N
# 134      134    134            금악주유소     제주특별자치도 제주시 한림읍 한창로 1249  2210.0  N
#
#         브랜드     구
# 194    자가상표   제주시
# 64   현대오일뱅크  서귀포시
# 193   SK에너지   제주시
# 192  NH-OIL   제주시
# 191   SK에너지   제주시
# ...

# %%
gas_station.sort_values(by='경유가격', ascending=True).head(10)
# Out:
#      index               주유소명                        주소    경유가격 셀프     브랜드  \
# 69      69           만남의광장주유소      서울 서초구 양재대로12길 73-71  1960.0  Y  알뜰(ex)
# 83      83  에쓰오일(주)직영 오토테크주유소  서울특별시 서초구  효령로 356 (서초동)  1969.0  Y   S-OIL
# 175    176     (주)타이거오일 신정주유소      서울 양천구 중앙로 226 (신정동)  1969.0  Y   SK에너지
# 48      48     에스오일(주) 염리동주유소      서울 마포구 백범로 126 (염리동)  1969.0  Y   S-OIL
# 359    367      극동유화(주) 항동주유소     서울 구로구 서해안로 2154 (항동)  1969.0  Y   S-OIL
# 406    415      극동유화(주) 대안주유소       서울 도봉구 마들로 574 (창동)  1969.0  Y   S-OIL
# 195    196      지에스칼텍스㈜ 화일주유소           서울 영등포구 도림로 415  1970.0  Y   GS칼텍스
# 177    178            가로공원주유소    서울 양천구 가로공원로 165 (신월동)  1976.0  N   SK에너지
# 293    299             뉴신정주유소     서울 강서구 곰달래로 207 (화곡동)  1976.0  N   알뜰주유소
# 294    300             화곡역주유소      서울 강서구 강서로 154 (화곡동)  1976.0  Y   알뜰주유소
#
#         구
# 69    서초구
# 83    서초구
# 175   양천구
# 48    마포구
# 359   구로구
# 406   도봉구
# 195  영등포구
# 177   양천구
# 293   강서구
# 294   강서구
